# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/capstone-jobs-dataset/jobs_dataset.csv

# %%
df = pd.read_csv('/kaggle/input/capstone-jobs-dataset/jobs_dataset.csv').sample(frac=1).reset_index(drop=True)
df
# Out:
#                                                   Title  \
# 0                        Strategic Partnerships Manager
# 1     Accounting, Finance | PT Putra Wijayakususma S...
# 2     Sales Manager (Korean Speaking) - Sports & Fas...
# 3                                           Stall Staff
# 4                               Cyber Security Engineer
# ...                                                 ...
# 5246               Production Supervisor (SJA Semarang)
# 5247       GoTo Financial - Payments Compliance Manager
# 5248          Gojek - Account Executive (North Jakarta)
# 5249                                    DevOps Engineer
# 5250                                   Technical Writer
#
#                                       Company  \
# 0                                Minor Hotels
# 1                            PT XL Axiata Tbk
# 2                         Aneka Jaya Swalayan
# 3     PT SANTOS JAYA ABADI (Kapal Api Global)
# 4                 PT. Intikom Berlian Mustika
# ...                                       ...
# 5246                                   Shopee
# 5247                               GoTo Group
# 5248                               GoTo Group
# 5249             PT. Erajaya Swasembada, Tbk.
# 5250           PT. Lintas Teknologi Indonesia
#
#                                Location                    Country  \
# 0             Jakarta Metropolitan Area  Jakarta Metropolitan Area
# 1          Malang, East Java, Indonesia                  Indonesia
# 2          Tangerang, Banten, Indonesia                  Indonesia
# 3        Sidoarjo, East Java, Indonesia                  Indonesia
# 4                    Jakarta, Indonesia                  Indonesia
# ...                                 ...                        ...
# 5246  Semarang, Central Java, Indonesia                  Indonesia
# 5247        Jakarta, Jakarta, Indonesia                  Indonesia
# 5248        Jakarta, Jakarta, Indonesia                  Indonesia
# 5249                 Jakarta, Indonesia                  Indonesia
# 5250    Tanah Abang, Jakarta, Indonesia                  Indonesia
#
#                                         Job Description  \
# 0     Strategic Planning & Execution: | Develop and ...
# 1                                             Not Found
# 2                                             Not Found
# 3                                             Not Found
# 4     Planning, implementing, managing, monitoring, ...
# ...                                                 ...
# 5246  Develop operational excellence strategy and im...
# 5247                                          Not Found
# 5248  Has existing relationship or able to bridge, d...
# 5249  Design, develop, and deploy modular cloud-base...
# 5250                                          Not Found
#
#                                        Job Requirements  \
# 0     Stakeholder Engagement: | Represent the organi...
# 1     Perform activities related to asset acquisitio...
# 2     Mampu melakukan riset pasar untuk memahami keb...
# 3     Melaksanakan fungsi Account Payable, aktiva te...
# 4     Troubleshooting security and network problems....
# ...                                                 ...
# 5246  Drives continuous improvement initiatives impl...
# 5247  Lead compliance in GoTo Financial online and o...
# 5248  Actively relate to Leads provided through Moti...
# 5249  Regularly review existing systems and make rec...
# 5250  Bachelor degree of IT/Computer Science | Min G...
#
#                                                    Link
# 0     https://id.linkedin.com/jobs/view/director-of-...
# 1     https://id.linkedin.com/jobs/view/asset-acquis...
# 2     https://id.linkedin.com/jobs/view/retail-buyer...
# 3     https://id.linkedin.com/jobs/view/stall-staff-...
# 4     https://id.linkedin.com/jobs/view/cyber-securi...
# ...                                                 ...
# 5246  https://id.linkedin.com/jobs/view/process-impr...
# 5247  https://id.linkedin.com/jobs/view/goto-financi...
# 5248  https://id.linkedin.com/jobs/view/gojek-accoun...
# 5249  https://id.linkedin.com/jobs/view/devops-engin...
# 5250  https://id.linkedin.com/jobs/view/technical-wr...
#
# [5251 rows x 7 columns]

# %%
# Ganti "Not Found" dengan NaN
df.replace("Not Found", np.nan, inplace=True)

# %%
# Hapus duplikat
df.drop_duplicates(subset=["Title", "Company", "Location"], inplace=True)

# %%
# Normalisasi teks
text_columns = ["Title", "Company", "Location", "Country", "Job Description", "Job Requirements"]
for col in text_columns:
    df[col] = df[col].str.lower().str.strip()

# %%
# Pisahkan lokasi
df[["City", "Region"]] = df["Location"].str.split(",", n=1, expand=True)
df["City"] = df["City"].str.strip()
df["Region"] = df["Region"].str.strip()

# %%
df
# Out:
#                                                   Title  \
# 0                        strategic partnerships manager
# 1     accounting, finance | pt putra wijayakususma s...
# 2     sales manager (korean speaking) - sports & fas...
# 3                                           stall staff
# 4                               cyber security engineer
# ...                                                 ...
# 5213                         fullstack developer golang
# 5221                                     tax specialist
# 5224  seamstress - tailor - disney cruise land - yog...
# 5240                              tax - legal & finance
# 5247       goto financial - payments compliance manager
#
#                                       Company  \
# 0                                minor hotels
# 1                            pt xl axiata tbk
# 2                         aneka jaya swalayan
# 3     pt santos jaya abadi (kapal api global)
# 4                 pt. intikom berlian mustika
# ...                                       ...
# 5213                      htc global services
# 5221                                skintific
# 5224                      anta southeast asia
# 5240                                skintific
# 5247                               goto group
#
#                                Location                    Country  \
# 0             jakarta metropolitan area  jakarta metropolitan area
# 1          malang, east java, indonesia                  indonesia
# 2          tangerang, banten, indonesia                  indonesia
# 3        sidoarjo, east java, indonesia                  indonesia
# 4                    jakarta, indonesia                  indonesia
# ...                                 ...                        ...
# 5213     sidoarjo, east java, indonesia                  indonesia
# 5221       tangerang, banten, indonesia                  indonesia
# 5224  yogyakarta, yogyakarta, indonesia                  indonesia
# 5240                 jakarta, indonesia                  indonesia
# 5247        jakarta, jakarta, indonesia                  indonesia
#
#                                         Job Description  \
# 0     strategic planning & execution: | develop and ...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     planning, implementing, managing, monitoring, ...
# ...                                                 ...
# 5213  develop and maintain secure, scalable fullstac...
# 5221  team leadership and management: manage and men...
# 5224  hr operations - ensures business compliance wi...
# 5240  team leadership and management: manage and men...
# 5247                                                NaN
#
#                                        Job Requirements  \
# 0     stakeholder engagement: | represent the organi...
# 1     perform activities related to asset acquisitio...
# 2     mampu melakukan riset pasar untuk memahami keb...
# 3     melaksanakan fungsi account payable, aktiva te...
# 4     troubleshooting security and network problems....
# ...                                                 ...
# 5213  work closely with product managers, business a...
# 5221  accounts receivable operations: oversee all as...
# 5224  business partnering - working directly with th...
# 5240  accounts receivable operations: oversee all as...
# 5247  lead compliance in goto financial online and o...
#
#                                                    Link  \
# 0     https://id.linkedin.com/jobs/view/director-of-...
# 1     https://id.linkedin.com/jobs/view/asset-acquis...
# 2     https://id.linkedin.com/jobs/view/retail-buyer...
# 3     https://id.linkedin.com/jobs/view/stall-staff-...
# 4     https://id.linkedin.com/jobs/view/cyber-securi...
# ...                                                 ...
# 5213  https://id.linkedin.com/jobs/view/full-stack-d...
# 5221  https://id.linkedin.com/jobs/view/accounts-rec...
# 5224  https://id.linkedin.com/jobs/view/indonesia-hu...
# 5240  https://id.linkedin.com/jobs/view/accounts-rec...
# 5247  https://id.linkedin.com/jobs/view/goto-financi...
#
#                            City                 Region
# 0     jakarta metropolitan area                   None
# 1                        malang   east java, indonesia
# 2                     tangerang      banten, indonesia
# 3                      sidoarjo   east java, indonesia
# 4                       jakarta              indonesia
# ...                         ...                    ...
# 5213                   sidoarjo   east java, indonesia
# 5221                  tangerang      banten, indonesia
# 5224                 yogyakarta  yogyakarta, indonesia
# 5240                    jakarta              indonesia
# 5247                    jakarta     jakarta, indonesia
#
# [2004 rows x 9 columns]

# %%
df_cleaned = df.dropna(subset=["Job Description", "Job Requirements"])

# %%
df_cleaned
# Out:
#                                                   Title  \
# 0                        strategic partnerships manager
# 4                               cyber security engineer
# 7                                      duty engineering
# 8                          finance & accounting officer
# 9                senior software engineer 1 - fullstack
# ...                                                 ...
# 5208                         fullstack developer golang
# 5213                         fullstack developer golang
# 5221                                     tax specialist
# 5224  seamstress - tailor - disney cruise land - yog...
# 5240                              tax - legal & finance
#
#                                Company                           Location  \
# 0                         minor hotels          jakarta metropolitan area
# 4          pt. intikom berlian mustika                 jakarta, indonesia
# 7                  padma resort legian            badung, bali, indonesia
# 8     pt astra digital arta (astrapay)        jakarta, jakarta, indonesia
# 9                               mekari        jakarta, jakarta, indonesia
# ...                                ...                                ...
# 5208                           vascomm     sidoarjo, east java, indonesia
# 5213               htc global services     sidoarjo, east java, indonesia
# 5221                         skintific       tangerang, banten, indonesia
# 5224               anta southeast asia  yogyakarta, yogyakarta, indonesia
# 5240                         skintific                 jakarta, indonesia
#
#                         Country  \
# 0     jakarta metropolitan area
# 4                     indonesia
# 7                     indonesia
# 8                     indonesia
# 9                     indonesia
# ...                         ...
# 5208                  indonesia
# 5213                  indonesia
# 5221                  indonesia
# 5224                  indonesia
# 5240                  indonesia
#
#                                         Job Description  \
# 0     strategic planning & execution: | develop and ...
# 4     planning, implementing, managing, monitoring, ...
# 7     diploma degree in hospitality management or eq...
# 8     support the continuous improvement of processe...
# 9     develop user interfaces with react js, underst...
# ...                                                 ...
# 5208  pengalaman kerja minimal 2 tahun sebagai fulls...
# 5213  develop and maintain secure, scalable fullstac...
# 5221  team leadership and management: manage and men...
# 5224  hr operations - ensures business compliance wi...
# 5240  team leadership and management: manage and men...
#
#                                        Job Requirements  \
# 0     stakeholder engagement: | represent the organi...
# 4     troubleshooting security and network problems....
# 7     minimum 2 years of experience in hospitality i...
# 8     oversee daily cash flow to maintain company li...
# 9     customize vertical products based on clients' ...
# ...                                                 ...
# 5208  mengembangkan aplikasi berbasis backend menggu...
# 5213  work closely with product managers, business a...
# 5221  accounts receivable operations: oversee all as...
# 5224  business partnering - working directly with th...
# 5240  accounts receivable operations: oversee all as...
#
#                                                    Link  \
# 0     https://id.linkedin.com/jobs/view/director-of-...
# 4     https://id.linkedin.com/jobs/view/cyber-securi...
# 7     https://id.linkedin.com/jobs/view/duty-enginee...
# 8     https://id.linkedin.com/jobs/view/finance-acco...
# 9     https://id.linkedin.com/jobs/view/ui-solution-...
# ...                                                 ...
# 5208  https://id.linkedin.com/jobs/view/fullstack-de...
# 5213  https://id.linkedin.com/jobs/view/full-stack-d...
# 5221  https://id.linkedin.com/jobs/view/accounts-rec...
# 5224  https://id.linkedin.com/jobs/view/indonesia-hu...
# 5240  https://id.linkedin.com/jobs/view/accounts-rec...
#
#                            City                 Region
# 0     jakarta metropolitan area                   None
# 4                       jakarta              indonesia
# 7                        badung        bali, indonesia
# 8                       jakarta     jakarta, indonesia
# 9                       jakarta     jakarta, indonesia
# ...                         ...                    ...
# 5208                   sidoarjo   east java, indonesia
# 5213                   sidoarjo   east java, indonesia
# 5221                  tangerang      banten, indonesia
# 5224                 yogyakarta  yogyakarta, indonesia
# 5240                    jakarta              indonesia
#
# [1364 rows x 9 columns]

# %%
df_cleaned.to_csv('jobs_cleaned.csv', index=False)
